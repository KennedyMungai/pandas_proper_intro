# %% [markdown]
# <h1>Pandas Intro</h1>

# %%
import pandas as pd

# %% [markdown]
# <p>An Empty Series</p>

# %%
my_series = pd.Series()
print(my_series)
# Out:
# Series([], dtype: object)

# %%
import numpy as np

# %%
my_array = np.array([10, 20, 30, 40, 50])
my_series = pd.Series(my_array)

print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# <p>Custom Indices</p>

# %%
my_series = pd.Series(my_array, index=["num1", "num2", "num3", "num4", "num5"])
print(my_series)
# Out:
# num1    10
# num2    20
# num3    30
# num4    40
# num5    50
# dtype: int64

# %% [markdown]
# <p>Passing Indices on series definition</p>

# %%
my_series = pd.Series([10, 20, 30, 40, 50], index=(["num1", "num2", "num3", "num4", "num5"]))
print(my_series)
# Out:
# num1    10
# num2    20
# num3    30
# num4    40
# num5    50
# dtype: int64

# %% [markdown]
# <p>Defining A Series Using Scalar Values</p>

# %%
my_series=pd.Series(25, index=(["num1", "num2", "num3", "num4", "num5"]))
print(my_series)
# Out:
# num1    25
# num2    25
# num3    25
# num4    25
# num5    25
# dtype: int64

# %% [markdown]
# <p>Defining a series using a dictionary</p>

# %%
my_dict = {
    "num1": 6,
    "num1": 7,
    "num1": 8
}

my_series = pd.Series(my_dict)
print(my_series)
# Out:
# num1    8
# dtype: int64

# %% [markdown]
# <p>Finding the Min and Max values in a series</p>

# %%
import pandas as pd
my_series = pd.Series([1, 2, 3, 4, 5])

print("Series Min")
print(np.min(my_series))
print("Series Max")
print(np.max(my_series))
# Out:
# Series Min
# 1
# Series Max
# 5

# %% [markdown]
# <p>The Mean in a series</p>

# %%
print(my_series.mean())
print(np.mean(my_series))
# Out:
# 3.0
# 3.0

# %% [markdown]
# <p>Finding the Median of a series</p>

# %%
print(my_series.median())
print(np.median(my_series))
# Out:
# 3.0
# 3.0

# %% [markdown]
# <p>Finding the data type of a series</p>

# %%
print(my_series.dtype)
# Out:
# int64

# %% [markdown]
# <p>Converting a pandas series to a list</p>

# %%
print(my_series.tolist())
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# <h2>Pandas DataFrame</h2>

# %% [markdown]
# <p>Empty DataFrame</p>

# %%
my_df = pd.DataFrame()
print(my_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# <p>Creating a Dataframe using a 2D list</p>

# %%
import pandas as pd
scores = [
    ["Mathematics", 85],
    ["English", 91],
    ["History", 95]
]

my_df = pd.DataFrame(scores, columns=["Subject", "Score"])
my_df
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      English     91
# 2      History     95

# %% [markdown]
# <P>Create a Dataframe using dictionaries</P>

# %%
scores = {
    'Subject': ["Mathematics", "History", "English", "Science", "Arts"],
    'Score': [98, 75, 68, 82, 99]
}

my_df = pd.DataFrame(scores)

print(my_df)
# Out:
#        Subject  Score
# 0  Mathematics     98
# 1      History     75
# 2      English     68
# 3      Science     82
# 4         Arts     99

# %% [markdown]
# <p>Creating a DataFrame using a List of strings</p>

# %%
import pandas as pd
scores = [
    {'Subject': 'Mathematics', 'Score': 90},
    {'Subject': 'English', 'Score': 75},
    {'Subject': 'Geography', 'Score': 85},
    {'Subject': 'History', 'Score': 80},
    {'Subject': 'Programming', 'Score': 100},
]

my_df = pd.DataFrame(scores)
print(my_df)
# Out:
#        Subject  Score
# 0  Mathematics     90
# 1      English     75
# 2    Geography     85
# 3      History     80
# 4  Programming    100

# %% [markdown]
# <p>A dataframe using a list if dictionaries using null items</p>

# %%
scores = [
    {'Subject': 'Mathematics', 'Score': 85},
    {'Subject': 'English', 'Score': 75},
    {'Subject': 'Geography', 'Score': 93},
    {'Subject': 'Geography', 'Score': 95},
    {'Subject': 'History', 'Score': 80},
    {'Score': 72}
]

my_df = pd.DataFrame(scores)
print(my_df)
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      English     75
# 2    Geography     93
# 3    Geography     95
# 4      History     80
# 5          NaN     72

# %% [markdown]
# <p>Using DataFrames to view sample data at the top of the record</p>

# %%
my_df.head(2)
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      English     75

# %% [markdown]
# <p>Using Dataframes to view sample data from the bottom of the record</p>

# %%
my_df.tail(2)
# Out:
#    Subject  Score
# 4  History     80
# 5      NaN     72

# %% [markdown]
# <p>Getting the summary of a Dataframe</p>

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  5 non-null      object
#  1   Score    6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %% [markdown]
# <p>Getting information on numeric columns for the dataframe</p>

# %%
my_df.describe()
# Out:
#            Score
# count   6.000000
# mean   83.333333
# std     9.395034
# min    72.000000
# 25%    76.250000
# 50%    82.500000
# 75%    91.000000
# max    95.000000

# %% [markdown]
# <h2>Importing data in Pandas</h2>

# %% [markdown]
# <p>Importing CSV files</p>

# %%
some_data = pd.read_csv('./Whatsgoodly - Thought Catalog Influencers.csv')
some_data.head(10)
# Out:
#                                             Question Segment Type
# 0  What do you think when an influencer is obviou...       Mobile  \
# 1  What do you think when an influencer is obviou...       Mobile
# 2  What do you think when an influencer is obviou...       Mobile
# 3  What do you think when an influencer is obviou...       Mobile
# 4  What do you think when an influencer is obviou...          Web
# 5  What do you think when an influencer is obviou...          Web
# 6  What do you think when an influencer is obviou...          Web
# 7  What do you think when an influencer is obviou...          Web
# 8  What do you think when an influencer is obviou...       Gender
# 9  What do you think when an influencer is obviou...       Gender
#
#   Segment Description                 Answer  Count  Percentage
# 0      Global results  Is this product cool?    268       0.226
# 1      Global results           This is lame    532       0.449
# 2      Global results       Get that money!     293       0.247
# 3      Global results       Other (comment)      91       0.077
# 4                 Web  Is this product cool?      0       0.000
# 5                 Web           This is lame      0       0.000
# 6                 Web       Get that money!       0       0.000
# 7                 Web       Other (comment)       0       0.000
# 8       Female voters  Is this product cool?     71       0.165
# 9       Female voters           This is lame    220       0.510

# %%
some_data.describe()
# Out:
#              Count   Percentage
# count  5460.000000  5460.000000
# mean     36.229121     0.249451
# std      91.652298     0.283424
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       4.000000     0.158000
# 75%      27.000000     0.400000
# max    1479.000000     1.000000

# %% [markdown]
# <p>Importing Data from MySql</p>

# %%
import os

import pymysql
from dotenv import find_dotenv, load_dotenv
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

load_dotenv(find_dotenv())

MYSQL_DB = os.environ.get("MYSQL_DB")
MYSQL_USERNAME = os.environ.get("MYSQL_USERNAME")
MYSQL_PASSWORD = os.environ.get("MYSQL_PASSWORD")
MYSQL_URL = os.environ.get("MYSQL_URL")
MYSQL_PORT = os.environ.get("MYSQL_PORT")

engine = create_engine(mysql+pymysql:// + MYSQL_USERNAME + ':' + MYSQL_PASSWORD + '@' + MYSQL_URL + ':' + int(MYSQL_PORT) + '/' + MYSQL_DB)

employees_df = pd.read_sql_table('city', con=engine)

print(employees_df)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pymysql/connections.py:616, in Connection.connect(self, sock)
#     615 try:
# --> 616     sock = socket.create_connection(
#     617         (self.host, self.port), self.connect_timeout, **kwargs
#     618     )
#     619     break
#
# File /usr/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File /usr/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1267 if not fairy:
# -> 1268     fairy = _ConnectionRecord.checkout(pool)
#    1270     if threadconns is not None:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pymysql/connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351 else:
# --> 352     self.connect()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pymysql/connections.py:668, in Connection.connect(self, sock)
#     667         print(exc.traceback)
# --> 668     raise exc
#     670 # If e is neither DatabaseError or IOError, It's a bug.
#     671 # But raising AssertionError hides original error.
#     672 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([Errno 111] Connection refused)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 19
#      15 MYSQL_PORT = os.environ.get("MYSQL_PORT")
#      17 engine = create_engine('mysql+pymysql://kennedymungai:xknightmare12873@127.0.0.1:3306/world')
# ---> 19 employees_df = pd.read_sql_table('city', con=engine)
#      21 print(employees_df)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/io/sql.py:334, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     331 if dtype_backend is lib.no_default:
#     332     dtype_backend = "numpy"  # type: ignore[assignment]
# --> 334 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     335     if not pandas_sql.has_table(table_name):
#     336         raise ValueError(f"Table {table_name} not found")
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/io/sql.py:830, in pandasSQL_builder(con, schema, need_transaction)
#     827     raise ImportError("Using URI string without sqlalchemy installed.")
#     829 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 830     return SQLDatabase(con, schema, need_transaction)
#     832 warnings.warn(
#     833     "pandas only supports SQLAlchemy connectable (engine/connection) or "
#     834     "database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 "
#    (...)
#     837     stacklevel=find_stack_level(),
#     838 )
#     839 return SQLiteDatabase(con)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/io/sql.py:1537, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1535     self.exit_stack.callback(con.dispose)
#    1536 if isinstance(con, Engine):
# -> 1537     con = self.exit_stack.enter_context(con.connect())
#    1538 if need_transaction and not con.in_transaction():
#    1539     self.exit_stack.enter_context(con.begin())
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3264, in Engine.connect(self)
#    3241 def connect(self) -> Connection:
#    3242     """Return a new :class:`_engine.Connection` object.
#    3243
#    3244     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3261
#    3262     """
# -> 3264     return self._connection_cls(self)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2426, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2424 elif should_wrap:
#    2425     assert sqlalchemy_exception is not None
# -> 2426     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2427 else:
#    2428     assert exc_info[1] is not None
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3266 def raw_connection(self) -> PoolProxiedConnection:
#    3267     """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269     The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287     """
# -> 3288     return self.pool.connect()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1267     if not fairy:
# -> 1268         fairy = _ConnectionRecord.checkout(pool)
#    1270         if threadconns is not None:
#    1271             threadconns.current = weakref.ref(fairy)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pymysql/connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     350     self._sock = None
#     351 else:
# --> 352     self.connect()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pymysql/connections.py:668, in Connection.connect(self, sock)
#     666     if DEBUG:
#     667         print(exc.traceback)
# --> 668     raise exc
#     670 # If e is neither DatabaseError or IOError, It's a bug.
#     671 # But raising AssertionError hides original error.
#     672 # So just reraise it.
#     673 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([Errno 111] Connection refused)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# <p>Handling Missing Values in Python (Imputation)</p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (8, 6)
sns.set_style("darkgrid")

titanic_data = sns.load_dataset("titanic")
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# <p>Filtering some of the numeric columns from the dataset to see if the contain any missing values</p>

# %%
titanic_data_2 = titanic_data[
    ['survived', 'pclass', 'age', 'fare']
]

titanic_data_2.head()
# Out:
#    survived  pclass   age     fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
titanic_data.isnull().mean()
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %% [markdown]
# <p>The mean and the median values for all the non-missing values in the age column</p>

# %%
median = titanic_data.age.median()
mean = titanic_data.age.mean()

print("Median")
print(median)
print("Mean")
print(mean)
# Out:
# Median
# 28.0
# Mean
# 29.69911764705882

# %%
titanic_data['Median_Age'] = titanic_data.age.fillna(median)
titanic_data['Mean_Age'] = titanic_data.age.fillna(mean)
titanic_data['Mean_Age'] = np.round(titanic_data['Mean_Age'], 2)
titanic_data.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0          0       3    male  22.0      1      0   7.2500        S   Third  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone  Median_Age  Mean_Age
# 0     man        True  NaN  Southampton    no  False        22.0      22.0
# 1   woman       False    C    Cherbourg   yes  False        38.0      38.0
# 2   woman       False  NaN  Southampton   yes   True        26.0      26.0
# 3   woman       False    C  Southampton   yes  False        35.0      35.0
# 4     man        True  NaN  Southampton    no   True        35.0      35.0
# 5     man        True  NaN   Queenstown    no   True        28.0      29.7
# 6     man        True    E  Southampton    no   True        54.0      54.0
# 7   child       False  NaN  Southampton    no  False         2.0       2.0
# 8   woman       False  NaN  Southampton   yes  False        27.0      27.0
# 9   child       False  NaN    Cherbourg   yes  False        14.0      14.0
# 10  child       False    G  Southampton   yes  False         4.0       4.0
# 11  woman       False    C  Southampton   yes   True        58.0      58.0
# 12    man        True  NaN  Southampton    no   True        20.0      20.0
# 13    man        True  NaN  Southampton    no  False        39.0      39.0
# 14  child       False  NaN  Southampton    no   True        14.0      14.0
# 15  woman       False  NaN  Southampton   yes   True        55.0      55.0
# 16  child       False  NaN   Queenstown    no  False         2.0       2.0
# 17    man        True  NaN  Southampton   yes   True        28.0      29.7
# 18  woman       False  NaN  Southampton    no  False        31.0      31.0
# 19  woman       False  NaN    Cherbourg   yes   True        28.0      29.7

# %% [markdown]
# <p>Plotting out the data</p>

# %%
fig = plt.figure()
ax = fig.add_subplot( 111 )
titanic_data['age'] .plot(kind='kde', ax=ax)
titanic_data['Median_Age'] .plot(kind='kde', ax=ax, color='red')
titanic_data['Mean_Age'] .plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot( 111 )
# ----> 3 titanic_data['age'] .plot(kind='kde', ax=ax)
#       4 titanic_data['Median_Age'] .plot(kind='kde', ax=ax, color='red')
#       5 titanic_data['Mean_Age'] .plot(kind='kde', ax=ax, color='green')
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:167, in HistPlot._make_plot(self)
#     163     kwds["weights"] = weights
#     165 y = reformat_hist_y_given_by(y, self.by)
# --> 167 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169 # when by is applied, show title for subplots to know which group it is
#     170 if self.by is not None:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:248, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     236 @classmethod
#     237 def _plot(
#     238     cls,
#    (...)
#     246     **kwds,
#     247 ):
# --> 248     from scipy.stats import gaussian_kde
#     250     y = remove_na_arraylike(y)
#     251     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# <p>Frequent Category Imputation</p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = [8, 6]
sns.set_style('darkgrid')

titanic_data = sns.load_dataset('titanic')

titanic_data = titanic_data[
    ["embark_town", "age", "fare"]
]

titanic_data.head()
titanic_data.isnull().mean()
# Out:
# embark_town    0.002245
# age            0.198653
# fare           0.000000
# dtype: float64

# %% [markdown]
# <p>Plotting the Embark Town data</p>

# %%
titanic_data.embark_town.value_counts().sort_values(ascending=False).plot()
plt.xlabel('Embark Town')
plt.ylabel('Number of passengers')
# Out:
# Text(0, 0.5, 'Number of passengers')

# %%
titanic_data.embark_town.mode()
# Out:
# 0    Southampton
# Name: embark_town, dtype: object

# %%
titanic_data.embark_town.fillna('Southampton', inplace=True)

# %%
titanic_data.embark_town.mode()
# Out:
# 0    Southampton
# Name: embark_town, dtype: object

# %%
titanic_data['age_mode'] = titanic_data.age.fillna(24)
titanic_data.head(20)
# Out:
#     embark_town   age     fare  age_mode
# 0   Southampton  22.0   7.2500      22.0
# 1     Cherbourg  38.0  71.2833      38.0
# 2   Southampton  26.0   7.9250      26.0
# 3   Southampton  35.0  53.1000      35.0
# 4   Southampton  35.0   8.0500      35.0
# 5    Queenstown   NaN   8.4583      24.0
# 6   Southampton  54.0  51.8625      54.0
# 7   Southampton   2.0  21.0750       2.0
# 8   Southampton  27.0  11.1333      27.0
# 9     Cherbourg  14.0  30.0708      14.0
# 10  Southampton   4.0  16.7000       4.0
# 11  Southampton  58.0  26.5500      58.0
# 12  Southampton  20.0   8.0500      20.0
# 13  Southampton  39.0  31.2750      39.0
# 14  Southampton  14.0   7.8542      14.0
# 15  Southampton  55.0  16.0000      55.0
# 16   Queenstown   2.0  29.1250       2.0
# 17  Southampton   NaN  13.0000      24.0
# 18  Southampton  31.0  18.0000      31.0
# 19    Cherbourg   NaN   7.2250      24.0

# %% [markdown]
# <p>The Kernel Density Estimation plot for the original age column</p>

# %%
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = (8, 6)

fig = plt.figure()
ax = fig.add_subplot(111)

titanic_data['age'].plot(kind='kde', ax=ax)

titanic_data['age_mode'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 8
#       5 fig = plt.figure()
#       6 ax = fig.add_subplot(111)
# ----> 8 titanic_data['age'].plot(kind='kde', ax=ax)
#      10 titanic_data['age_mode'].plot(kind='kde', ax=ax, color='red')
#      12 lines, labels = ax.get_legend_handles_labels()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:167, in HistPlot._make_plot(self)
#     163     kwds["weights"] = weights
#     165 y = reformat_hist_y_given_by(y, self.by)
# --> 167 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169 # when by is applied, show title for subplots to know which group it is
#     170 if self.by is not None:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:248, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     236 @classmethod
#     237 def _plot(
#     238     cls,
#    (...)
#     246     **kwds,
#     247 ):
# --> 248     from scipy.stats import gaussian_kde
#     250     y = remove_na_arraylike(y)
#     251     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# <p>Missing Category Imputation</p>

# %%
plt.rcParams["figure.figsize"] = (8, 6)
sns.set_style("darkgrid")

titanic_data = sns.load_dataset('titanic')
titanic_data = titanic_data[
    ["embark_town", "age", "fare"]
]

titanic_data.head()
titanic_data.isnull().mean()
# Out:
# embark_town    0.002245
# age            0.198653
# fare           0.000000
# dtype: float64

# %%
titanic_data.embark_town.fillna('Missing', inplace=True)

# %% [markdown]
# <h2>Manipulating Dataframes</h2>

# %% [markdown]
# <p>Selecting Data using Indexing and Slicing</p>

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

titanic_data = sns.load_dataset('titanic')
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# <p>Selecting Individual columns for a dataframe</p>

# %%
print(titanic_data['class'])
type(titanic_data['class'])
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']
# pandas.core.series.Series

# %% [markdown]
# <p>Selecting Several Dataframe columns</p>

# %%
print(type(titanic_data[['class', 'sex', 'age']]))
titanic_data[['class', 'sex', 'age']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       class     sex   age
# 0     Third    male  22.0
# 1     First  female  38.0
# 2     Third  female  26.0
# 3     First  female  35.0
# 4     Third    male  35.0
# ..      ...     ...   ...
# 886  Second    male  27.0
# 887   First  female  19.0
# 888   Third  female   NaN
# 889   First    male  26.0
# 890   Third    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# <p>Filtering rows based on a column value</p>

# %%
my_df = titanic_data[titanic_data['sex'] == 'male']
my_df.head()
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked  class    who
# 0         0       3  male  22.0      1      0   7.2500        S  Third    man  \
# 4         0       3  male  35.0      0      0   8.0500        S  Third    man
# 5         0       3  male   NaN      0      0   8.4583        Q  Third    man
# 6         0       1  male  54.0      0      0  51.8625        S  First    man
# 7         0       3  male   2.0      3      1  21.0750        S  Third  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 4        True  NaN  Southampton    no   True
# 5        True  NaN   Queenstown    no   True
# 6        True    E  Southampton    no   True
# 7       False  NaN  Southampton    no  False

# %% [markdown]
# <p>Multiple Conditions When Filtering the Records</p>

# %%
my_df = titanic_data[(titanic_data['sex'] == 'male') & (titanic_data['class'] == 'First')]
my_df.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch      fare embarked  class  who
# 6          0       1  male  54.0      0      0   51.8625        S  First  man  \
# 23         1       1  male  28.0      0      0   35.5000        S  First  man
# 27         0       1  male  19.0      3      2  263.0000        S  First  man
# 30         0       1  male  40.0      0      0   27.7208        C  First  man
# 34         0       1  male  28.0      1      0   82.1708        C  First  man
#
#     adult_male deck  embark_town alive  alone
# 6         True    E  Southampton    no   True
# 23        True    A  Southampton   yes   True
# 27        True    C  Southampton    no  False
# 30        True  NaN    Cherbourg    no   True
# 34        True  NaN    Cherbourg    no  False

# %% [markdown]
# <p>Filtering using the isin function</p>

# %%
ages = [20, 21, 22]

age_dataset = titanic_data[titanic_data['age'].isin(ages)]
age_dataset.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch   fare embarked   class
# 0          0       3    male  22.0      1      0   7.25        S   Third  \
# 12         0       3    male  20.0      0      0   8.05        S   Third
# 37         0       3    male  21.0      0      0   8.05        S   Third
# 51         0       3    male  21.0      0      0   7.80        S   Third
# 56         1       2  female  21.0      0      0  10.50        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 12    man        True  NaN  Southampton    no   True
# 37    man        True  NaN  Southampton    no   True
# 51    man        True  NaN  Southampton    no   True
# 56  woman       False  NaN  Southampton   yes   True

# %% [markdown]
# <p>Filtering data using the loc function</p>

# %%
scores = [
    {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B',
    'Remarks': 'Good', },
    {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks':
    'Excellent'},
    {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks':
    'Fair'},
    {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks':
    'Fair'},
    {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks':
    'Excellent'},
]

my_df = pd.DataFrame(scores)
my_df.head()
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Excellent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Excellent

# %%
print(my_df.loc[2])
type(my_df.loc[2])
# Out:
# Subject    English
# Score           76
# Grade            C
# Remarks       Fair
# Name: 2, dtype: object
# pandas.core.series.Series

# %%
my_df.loc[2:4]
# Out:
#    Subject  Score Grade    Remarks
# 2  English     76     C       Fair
# 3  Science     72     C       Fair
# 4     Arts     95     A  Excellent

# %%
my_df.loc[2:4, ["Grade", "Score"]]
# Out:
#   Grade  Score
# 2     C     76
# 3     C     72
# 4     A     95

# %% [markdown]
# <p>A Dataframe with named indices</p>

# %%
scores = [
    {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B','Remarks': 'Good', },
    {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks':'Excellent'},
    {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks':'Excellent'},
]

my_df = pd.DataFrame(scores, index=["Student1", "Student2","Student3", "Student4", "Student5"])
my_df
# Out:
#               Subject  Score Grade    Remarks
# Student1  Mathematics     85     B       Good
# Student2      History     98     A  Excellent
# Student3      English     76     C       Fair
# Student4      Science     72     C       Fair
# Student5         Arts     95     A  Excellent

# %%
my_df.loc["Student1"]
# Out:
# Subject    Mathematics
# Score               85
# Grade                B
# Remarks           Good
# Name: Student1, dtype: object

# %%
index_list = ["Student1", "Student2"]
my_df.loc[index_list]
# Out:
#               Subject  Score Grade    Remarks
# Student1  Mathematics     85     B       Good
# Student2      History     98     A  Excellent

# %% [markdown]
# <p>FIltering for a specific value in a named index</p>

# %%
my_df.loc["Student1", "Grade"]
# Out:
# 'B'

# %% [markdown]
# <h2>Dropping Rows and Column using the Drop function</h2>

# %% [markdown]
# <p>Dropping Rows</p>

# %%
scores = [
    {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B','Remarks': 'Good', },
    {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks':'Excellent'},
    {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks':'Excellent'},
]

my_df = pd.DataFrame(scores)
my_df.head()
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Excellent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Excellent

# %%
my_df2 = my_df.drop([1, 4])
my_df2.head()
# Out:
#        Subject  Score Grade Remarks
# 0  Mathematics     85     B    Good
# 2      English     76     C    Fair
# 3      Science     72     C    Fair

# %%
my_df2.reset_index()
# Out:
#    index      Subject  Score Grade Remarks
# 0      0  Mathematics     85     B    Good
# 1      2      English     76     C    Fair
# 2      3      Science     72     C    Fair

# %% [markdown]
# <p>Dropping Columns using the Drop function</p>

# %%
my_df2 = my_df.drop(["Subject", "Grade"], axis=1)
my_df2.head()
# Out:
#    Score    Remarks
# 0     85       Good
# 1     98  Excellent
# 2     76       Fair
# 3     72       Fair
# 4     95  Excellent

# %% [markdown]
# <h2>Filtering Rows</h2>

# %%
scores = [
    {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B','Remarks': 'Good', },
    {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks':'Excellent'},
    {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks':'Fair'},
    {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks':'Excellent'},
]

my_df = pd.DataFrame(scores)
my_df.head()
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Excellent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Excellent

# %%
my_df2 = my_df.filter([1, 3, 4], axis = 0)
my_df2.head()
# Out:
#    Subject  Score Grade    Remarks
# 1  History     98     A  Excellent
# 3  Science     72     C       Fair
# 4     Arts     95     A  Excellent

# %%
my_df2.reset_index()
# Out:
#    index  Subject  Score Grade    Remarks
# 0      1  History     98     A  Excellent
# 1      3  Science     72     C       Fair
# 2      4     Arts     95     A  Excellent

# %% [markdown]
# <h2>Sorting DataFrames</h2>

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Set the default style for plotting
sns.set_style("darkgrid")

titanic_data = sns.load_dataset("titanic")
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# <p>Sorting the titanic dataset in order of the passenger's age</p>

# %%
age_sorted_data = titanic_data.sort_values(by=['age'])
age_sorted_data.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 803         1       3    male  0.42      0      1   8.5167        C   Third  \
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male   NaN      0      0   7.2292        C   Third
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 868         0       3    male   NaN      0      0   9.5000        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [891 rows x 15 columns]

# %% [markdown]
# <p>The data by the age descending</p>

# %%
age_sorted_data = titanic_data.sort_values(by=['age'], ascending=False)
age_sorted_data.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who
# 630         1       1  male  80.0      0      0  30.0000        S  First  man  \
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
# 493        True  NaN    Cherbourg    no   True
# 96         True    A    Cherbourg    no   True
# 116        True  NaN   Queenstown    no   True

# %% [markdown]
# <p>Sorting Values using the by attribute</p>

# %%
age_sorted_data = titanic_data.sort_values(by=['age', 'fare'], ascending=False)
age_sorted_data.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who
# 630         1       1  male  80.0      0      0  30.0000        S  First  man  \
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
# 493        True  NaN    Cherbourg    no   True
# 96         True    A    Cherbourg    no   True
# 116        True  NaN   Queenstown    no   True

# %% [markdown]
# <h2>Pandas Unique and Count functions</h2>

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# <p>The dataframe filtered using unique classes</p>

# %%
titanic_data['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %% [markdown]
# <p>Not Unique</p>

# %%
titanic_data['class'].nunique()
# Out:
# 3

# %% [markdown]
# <p>The count of values in a dataframe</p>

# %%
titanic_data.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# <p>The number of records with unique values</p>

# %%
titanic_data['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %% [markdown]
# <h2>Data Grouping, Aggregation and Merging with Pandas</h2>

# %% [markdown]
# <h3>Grouping Data using Group By</h3>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style('darkgrid')

titanic_data = sns.load_dataset('titanic')
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_data_gbclass = titanic_data.groupby('class')
type(titanic_data_gbclass)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# <p>The number of groups in a DataFrames Group By object</p>

# %%
titanic_data_gbclass.ngroups
# Out:
# 3

# %% [markdown]
# <p>Using the size function to get the number of records in each group</p>

# %%
titanic_data_gbclass.size()
# Out:
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %% [markdown]
# <p>Getting the row indices for records in a particular group</p>

# %%
titanic_data_gbclass.groups["First"]
# Out:
# Index([  1,   3,   6,  11,  23,  27,  30,  31,  34,  35,
#        ...
#        853, 856, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=216)

# %% [markdown]
# <p>The first and last records in each particular group</p>

# %%
titanic_data_gbclass.first()
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked    who
# class
# First          1       1  female  38.0      1      0  71.2833        C  woman  \
# Second         1       2  female  14.0      1      0  30.0708        C  child
# Third          0       3    male  22.0      1      0   7.2500        S    man
#
#         adult_male deck  embark_town alive  alone
# class
# First        False    C    Cherbourg   yes  False
# Second       False    D    Cherbourg   yes  False
# Third         True    G  Southampton    no  False

# %%
titanic_data_gbclass.last()
# Out:
#         survived  pclass   sex   age  sibsp  parch   fare embarked  who
# class
# First          1       1  male  26.0      0      0  30.00        C  man  \
# Second         0       2  male  27.0      0      0  13.00        S  man
# Third          0       3  male  32.0      0      0   7.75        Q  man
#
#         adult_male deck  embark_town alive  alone
# class
# First         True    C    Cherbourg   yes   True
# Second        True    E  Southampton    no   True
# Third         True    E   Queenstown    no   True

# %% [markdown]
# <p>Creating Dataframes from the various groups</p>

# %%
titanic_first_class = titanic_data_gbclass.get_group("First")
titanic_second_class = titanic_data_gbclass.get_group("Second")
titanic_third_class = titanic_data_gbclass.get_group("Third")

# %%
print("The first dataframe containing only first class passengers")
titanic_first_class.head()
# Out:
# The first dataframe containing only first class passengers
# The second dataframe containing only second class passengers
# The third dataframe containing only third class passengers
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 7  child       False  NaN  Southampton    no  False

# %%
print("The second dataframe containing only second class passengers")
titanic_second_class.head()
# Out:
# The second dataframe containing only second class passengers
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 9          1       2  female  14.0      1      0  30.0708        C  Second  \
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# 21         1       2    male  34.0      0      0  13.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 9   child       False  NaN    Cherbourg   yes  False
# 15  woman       False  NaN  Southampton   yes   True
# 17    man        True  NaN  Southampton   yes   True
# 20    man        True  NaN  Southampton    no   True
# 21    man        True    D  Southampton   yes   True

# %%
print("The third dataframe containing only third class passengers")
titanic_third_class.head()
# Out:
# The third dataframe containing only third class passengers
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 7  child       False  NaN  Southampton    no  False

# %% [markdown]
# <p>Getting the aggregate maximum of all the groups</p>

# %%
titanic_data_gbclass.age.max()
# Out:
# class
# First     80.0
# Second    70.0
# Third     74.0
# Name: age, dtype: float64

# %% [markdown]
# <p>Using the agg function to get the aggregate information from all the groups</p>

# %%
titanic_data_gbclass.fare.agg(['max', 'min', 'count', 'median', 'mean'])
# Out:
#              max  min  count   median       mean
# class
# First   512.3292  0.0    216  60.2875  84.154687
# Second   73.5000  0.0    184  14.2500  20.662183
# Third    69.5500  0.0    491   8.0500  13.675550

# %% [markdown]
# <h3>Concatenating and Merging Data</h3>

# %% [markdown]
# <p>Concatenating the rows of the titanic data</p>

# %%
print(titanic_first_class.shape)
print(titanic_second_class.shape)
# Out:
# (216, 15)
# (184, 15)

# %% [markdown]
# <p>Concatenating the first two classes</p>

# %%
titanic_first_two_classes = titanic_first_class.append(titanic_second_class, ignore_index=True)
print(titanic_first_two_classes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2335/3870099237.py in ?()
# ----> 1 titanic_first_two_classes = titanic_first_class.append(titanic_second_class, ignore_index=True)
#       2 print(titanic_first_two_classes)
#
# ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# <h2>Pandas for data visualization</h2>

# %% [markdown]
# <p>Loading Datasets with Pandas</p>

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# <p>Plotting Histograms with Pandas</p>

# %%
sns.set_style("darkgrid")
titanic_data['age'].hist()
# Out:
# <Axes: >

# %%
sns.set_style("darkgrid")
titanic_data['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <p>The histogram data with the number if bins increased</p>

# %%
sns.set_style('darkgrid')
titanic_data['age'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# <p>A Histogram with 20 bins set to the color Orange</p>

# %%
titanic_data['age'].hist(bins=20, color = 'orange')
# Out:
# <Axes: >

# %% [markdown]
# <h3>Pandas Line Plots</h3>

# %% [markdown]
# <p>Loading up flights data</p>

# %%
flights_data = sns.load_dataset('flights')
flights_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# <p>A simple line graph for the flight data</p>

# %%
flights_data.plot.line(y="passengers", figsize=(8,6))
# Out:
# <Axes: >

# %%
flights_data.plot.line(y="passengers", figsize=(8, 6), color='orange')
# Out:
# <Axes: >

# %% [markdown]
# <h3>Pandas Scatter Plots</h3>

# %% [markdown]
# <p>Simple Scatter Plot</p>

# %%
flights_data.plot.scatter(x='year', y='passengers', figsize=(8, 6), color='red')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# <h3>Pandas Bar Plots</h3>

# %% [markdown]
# <p>A simple Bar Plot to show the average age of male and female passengers</p>

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sex_mean = titanic_data.groupby(("sex"))["age"].mean()
print(sex_mean)
print(type(sex_mean.to_list()))
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64
# <class 'list'>

# %% [markdown]
# <p>Creating a Pandas Dataframe with two columns and plotted a bar plot</p>

# %%
df = pd.DataFrame({'Gender': ['Female', 'Male'], 'Age':sex_mean.to_list()})
ax = df.plot.bar(x="Gender", y="Age", figsize=(8,6))

# %% [markdown]
# <p>Plotting a horizontal bar graph of the sex mean data</p>

# %%
df = pd.DataFrame({"Gender": ["Female", "Male"], 'Age':sex_mean.tolist()})
ax = df.plot.barh(x="Gender", y="Age", figsize=(8, 6))

# %% [markdown]
# <h3>Pandas Box Plots</h3>

# %% [markdown]
# <p>Simple Titanic Box Plot</p>

# %%
titanic_data.plot.box(figsize=(10, 8))
# Out:
# <Axes: >

# %% [markdown]
# <h3>Pandas Hexagonal Plots</h3>

# %% [markdown]
# <p>Loading the tips dataset</p>

# %%
tips_data = sns.load_dataset('tips')
tips_data.plot.hexbin(x='total_bill', y='tip', gridsize = 20, figsize=(8, 6))
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips_data = sns.load_dataset('tips')
tips_data.plot.hexbin(x='total_bill', y='tip', gridsize = 20, figsize=(8, 6), color='blue')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# <h2>Pandas Kernel Density Plots</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

tips_data = sns.load_dataset('tips')

# %%
tips_data.plot.hexbin(x='total_bill', y='tip', gridsize= 20 ,
figsize=( 8 , 6 ), color = 'blue')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips_data.plot.kde( y='tip', figsize=(8,6), color = 'blue')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tips_data.plot.kde( y='tip', figsize=(8,6), color = 'blue')
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_core.py:1459, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1353 def kde(self, bw_method=None, ind=None, **kwargs) -> PlotAccessor:
#    1354     """
#    1355     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1356
#    (...)
#    1457         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1458     """
# -> 1459     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:167, in HistPlot._make_plot(self)
#     163     kwds["weights"] = weights
#     165 y = reformat_hist_y_given_by(y, self.by)
# --> 167 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169 # when by is applied, show title for subplots to know which group it is
#     170 if self.by is not None:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:248, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     236 @classmethod
#     237 def _plot(
#     238     cls,
#    (...)
#     246     **kwds,
#     247 ):
# --> 248     from scipy.stats import gaussian_kde
#     250     y = remove_na_arraylike(y)
#     251     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# <h2>Pandas Pie Chart</h2>

# %%
sns.set_style('darkgrid')
sns.set_context('poster')

titanic_data = sns.load_dataset('titanic')
titanic_data.head()

titanic_data.groupby('Pclass').size().plot(kind='pie', y='Pclass', label='Class', autopct = '%1.1f%%',figsize = (10, 8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 7
#       4 titanic_data = sns.load_dataset('titanic')
#       5 titanic_data.head()
# ----> 7 titanic_data.groupby('Pclass').size().plot(kind='pie', y='Pclass', label='Class', autopct = '%1.1f%%',figsize = (10, 8))
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/frame.py:8262, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8259     raise TypeError("You have to supply one of 'by' and 'level'")
#    8260 axis = self._get_axis_number(axis)
# -> 8262 return DataFrameGroupBy(
#    8263     obj=self,
#    8264     keys=by,
#    8265     axis=axis,
#    8266     level=level,
#    8267     as_index=as_index,
#    8268     sort=sort,
#    8269     group_keys=group_keys,
#    8270     observed=observed,
#    8271     dropna=dropna,
#    8272 )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'Pclass'

# %% [markdown]
# <h2>Handling Time Series Data with Pandas</h2>

# %% [markdown]
# <h3>Time series intro</h3>

# %%
import pandas as pd
import numpy as np

from datetime import datetime

dates = pd.date_range(start='1/1/2021', end='6/30/2021')
print(len(dates))
print(dates)
# Out:
# 181
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25', '2021-06-26', '2021-06-27', '2021-06-28',
#                '2021-06-29', '2021-06-30'],
#               dtype='datetime64[ns]', length=181, freq='D')

# %%
type(dates[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# <p>A simple dataframe containing dates and some random numbers</p>

# %%
date_df = pd.DataFrame(dates, columns=['Date'])
date_df['Temperature'] = np.random.randint(0, 50, size=(len(dates)))
date_df.head()
# Out:
#         Date  Temperature
# 0 2021-01-01           49
# 1 2021-01-02           48
# 2 2021-01-03           12
# 3 2021-01-04           31
# 4 2021-01-05            0

# %% [markdown]
# <p>COnverting TimeStamps to dates and then setting the converted date type column as the index column</p>

# %%
date_df['Date'] = pd.to_datetime(date_df['Date'])
date_df = date_df.set_index('Date')

date_df.head()
# Out:
#             Temperature
# Date
# 2021-01-01           49
# 2021-01-02           48
# 2021-01-03           12
# 2021-01-04           31
# 2021-01-05            0

# %% [markdown]
# <p>Plotting out the data</p>

# %%
import seaborn as sns

sns.set_style('darkgrid')
date_df.plot.line(y="Temperature", figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <h4>Time Resampling And Shifting</h4>

# %%
sns.set_style('darkgrid')

google_stock = pd.read_csv('./google_stock_price.csv')
google_stock.head()
# Out:
#          Date    Open    High     Low   Close      Volume
# 0  05/19/2023  124.20  126.48  122.72  123.25  30,268,859
# 1  05/18/2023  121.56  123.90  121.49  123.52  27,014,471
# 2  05/17/2023  120.18  122.28  119.46  121.48  26,659,561
# 3  05/16/2023  116.83  121.20  116.83  120.09  32,370,109
# 4  05/15/2023  116.49  118.80  116.48  116.96  22,107,869

# %% [markdown]
# <p>Plotting the google stock data</p>

# %%
google_stock['Date'] = google_stock['Date'].apply(pd.to_datetime)
google_stock.set_index('Date', inplace=True)
google_stock.plot.line(y='Open', figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <p>Performing time sampling and time shifting with time series data</p>

# %%
google_stock.resample(rule='M').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '29,191,74037,586,02031,558,22060,386,38037,899,34030,287,48029,924,42051,301,920'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 google_stock.resample(rule='M').mean()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/resample.py:979, in Resampler.mean(self, numeric_only, *args, **kwargs)
#     977 maybe_warn_args_and_kwargs(type(self), "mean", args, kwargs)
#     978 nv.validate_resampler_func("mean", args, kwargs)
# --> 979 return self._downsample("mean", numeric_only=numeric_only)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/resample.py:1297, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    1293     return self.asfreq()
#    1295 # we are downsampling
#    1296 # we want to call the actual grouper method here
# -> 1297 result = obj.groupby(self.grouper, axis=self.axis).aggregate(how, **kwargs)
#    1299 return self._wrap_result(result)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/internals/managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/internals/blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/series.py:4666, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4661     raise TypeError(
#    4662         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4663         "with non-numeric dtypes."
#    4664     )
#    4665 with np.errstate(all="ignore"):
# -> 4666     return op(delegate, skipna=skipna, **kwds)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/python/pandas_proper_intro/pandas/lib/python3.10/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert 29,191,74037,586,02031,558,22060,386,38037,899,34030,287,48029,924,42051,301,920 to numeric

# %%
google_stock['Open'].resample('A').mean()
# Out:
# Date
# 2022-12-31    105.102628
# 2023-12-31    100.632604
# Freq: A-DEC, Name: Open, dtype: float64

# %% [markdown]
# <p>Plotting out the results of a resample function based on aggregate values</p>

# %%
google_stock['Open'].resample('A').mean().plot(kind='bar', figsize=(8, 6), color='orange')
# Out:
# <Axes: xlabel='Date'>
